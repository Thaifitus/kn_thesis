# %% [markdown]
# Thesis implementation [Knowledge Neurons in Pretrained Transformers](https://github.com/Thaifitus/knowledge-neurons-thesis.git) execution.

# %% [markdown]
# ## Clone repository

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
'''
git clone and change working directory using local Colab.
'''

# !git clone https://github.com/Thaifitus/knowledge-neurons-thesis.git
# %cd /content/knowledge-neurons-thesis/src
# Out:
# '\ngit clone and change working directory using local Colab.\n'

# %%
'''
git clone and change working directory using Google Drive.
'''

# %cd /content/drive/MyDrive/"Colab Notebooks"
# !mkdir kn
# %cd ./kn
# !git clone --branch hoangthai https://github.com/Thaifitus/knowledge-neurons-thesis.git
# %cd ./knowledge-neurons-thesis
# Out:
# '\ngit clone and change working directory using Google Drive.\n'

# %%
'''
cd if already has the repository.
'''

# %cd /content/drive/MyDrive/"Colab Notebooks"/kn/knowledge-neurons-thesis/src
# Out:
# /content/drive/MyDrive/Colab Notebooks/kn/knowledge-neurons-thesis/src

# %% [markdown]
# ## Install packages

# %%
# !pip install jsonlines
# !pip install transformers==4.20.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 43.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 85.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.41.1
#     Uninstalling transformers-4.41.1:
#       Successfully uninstalled transformers-4.41.1
# ...

# %% [markdown]
# ### /src/2_get_kn.py

# %%
# !python 2_get_kn.py
# Out:
# ===========> parsing important position in P30..., mode_ratio_bag=0.7
# ===========> parsing important position in P30..., mode_ratio_bag=0.7
# ===========> parsing important position in P30..., mode_ratio_bag=0.75
# ===========> parsing important position in P30..., mode_ratio_bag=0.8
# ***** TREx-all-P30.rlt.jsonl KNs filtered. Costing time: 17.4933 seconds *****
# ===========> parsing important position in P364..., mode_ratio_bag=0.7
# ===========> parsing important position in P364..., mode_ratio_bag=0.75
# ===========> parsing important position in P364..., mode_ratio_bag=0.8
# ===========> parsing important position in P364..., mode_ratio_bag=0.8500000000000001
# ===========> parsing important position in P364..., mode_ratio_bag=0.7
# ***** TREx-all-P364.rlt.jsonl KNs filtered. Costing time: 23.5717 seconds *****
# ===========> parsing important position in P108..., mode_ratio_bag=0.7
# ===========> parsing important position in P108..., mode_ratio_bag=0.75
# ...
