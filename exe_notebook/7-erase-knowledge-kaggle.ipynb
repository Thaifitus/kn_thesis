# %% [markdown]
# Thesis implementation [Knowledge Neurons in Pretrained Transformers](https://github.com/Thaifitus/knowledge-neurons-thesis.git) execution.

# %% [markdown]
# # Clone repository

# %%
'''
git clone specified branch.
'''

# !git clone --branch main https://github.com/Thaifitus/determining_and_erasing_kns_in_transformer_thesis.git
# Out:
# Cloning into 'knowledge-neurons-thesis'...
# remote: Enumerating objects: 358, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 358 (delta 70), reused 79 (delta 40), pack-reused 233
# Receiving objects: 100% (358/358), 156.54 MiB | 14.81 MiB/s, done.
# Resolving deltas: 100% (140/140), done.
# Updating files: 100% (161/161), done.

# %%
'''
cd if already has the repository.
'''

# %cd /kaggle/working/determining_and_erasing_kns_in_transformer_thesis/src/
# Out:
# /kaggle/working/knowledge-neurons-thesis/src

# %% [markdown]
# # Install packages

# %%
# !pip install jsonlines
# !pip install transformers==4.20.0
# Out:
# Collecting jsonlines
#   Obtaining dependency information for jsonlines from https://files.pythonhosted.org/packages/f8/62/d9ba6323b9202dd2fe166beab8a86d29465c41a0288cbe229fac60c1ab8d/jsonlines-4.0.0-py3-none-any.whl.metadata
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonlines) (23.1.0)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Installing collected packages: jsonlines
# Successfully installed jsonlines-4.0.0
# Collecting transformers==4.20.0
#   Obtaining dependency information for transformers==4.20.0 from https://files.pythonhosted.org/packages/2f/bb/049c65b3f1821e69b7c625bcd877c709b7d155f443b9ff53fd3cdd8c077d/transformers-4.20.0-py3-none-any.whl.metadata
#   Downloading transformers-4.20.0-py3-none-any.whl.metadata (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.3/77.3 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers==4.20.0) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from transformers==4.20.0) (0.20.2)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers==4.20.0) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers==4.20.0) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers==4.20.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers==4.20.0) (2023.8.8)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers==4.20.0) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1 (from transformers==4.20.0)
#   Obtaining dependency information for tokenizers!=0.11.3,<0.13,>=0.11.1 from https://files.pythonhosted.org/packages/d4/be/2bba6943ee32f47a85ec72f5d7fdb943804ef42cc9babc922d010cfa05a9/tokenizers-0.12.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata
#   Downloading tokenizers-0.12.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.5 kB)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers==4.20.0) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.20.0) (2023.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.20.0) (4.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers==4.20.0) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.20.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.20.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.20.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.20.0) (2023.11.17)
# Downloading transformers-4.20.0-py3-none-any.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 50.0 MB/s eta 0:00:0000:0100:01
# Downloading tokenizers-0.12.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 79.6 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.0
#     Uninstalling tokenizers-0.15.0:
#       Successfully uninstalled tokenizers-0.15.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.36.2
#     Uninstalling transformers-4.36.2:
#       Successfully uninstalled transformers-4.36.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kaggle-environments 1.14.3 requires transformers>=4.33.1, but you have transformers 4.20.0 which is incompatible.
# Successfully installed tokenizers-0.12.1 transformers-4.20.0

# %% [markdown]
# # /src/7_run_erase.sh

# %%
# !bash 7_run_erase.sh P937
# Out:
# Downloading: 100%|███████████████████████████| 208k/208k [00:00<00:00, 3.04MB/s]
# Downloading: 100%|███████████████████████████| 49.0/49.0 [00:00<00:00, 44.7kB/s]
# Downloading: 100%|██████████████████████████████| 570/570 [00:00<00:00, 486kB/s]
# evaluating P937...
# [('10@1122', 899), ('10@739', 638), ('10@472', 637), ('9@369', 555), ('11@1657', 464), ('8@2645', 323), ('9@2125', 292), ('10@1294', 284), ('9@2994', 284), ('8@1519', 247), ('11@622', 236), ('9@2700', 208), ('10@183', 202), ('11@1384', 168), ('9@710', 153), ('9@2058', 153), ('9@1311', 131), ('10@3008', 117), ('8@1536', 114), ('10@126', 102)]
# Downloading: 100%|███████████████████████████| 386M/386M [00:10<00:00, 39.3MB/s]
#
# erasing -- kn_num: 20
#
# ***** P937 erased. Costing time: 8644.8430 seconds *****
# ======================================== P937 ===========================================
# original accuracy: 0.3338
# erased accuracy: 0.1229
# erased ratio: 0.6319
# # Kneurons: 20
# original ppl: 58.04
# erased ppl: 140.0
# ppl increasing ratio: -1.412
# (for other) original accuracy: 0.2272
# (for other) erased accuracy: 0.2234
# (for other) erased ratio: 0.01694
# (for other) original ppl: 138.0
# (for other) erased ppl: 151.9
# (for other) ppl increasing ratio: -0.1008
