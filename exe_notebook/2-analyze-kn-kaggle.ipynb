# %% [markdown]
# # Clone repository

# %%
'''
git clone specified branch.
'''

# !git clone --branch main https://github.com/Thaifitus/determining_and_erasing_kns_in_transformer_thesis.git
# Out:
# Cloning into 'knowledge-neurons-thesis'...
# remote: Enumerating objects: 358, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 358 (delta 70), reused 79 (delta 40), pack-reused 233
# Receiving objects: 100% (358/358), 156.54 MiB | 14.81 MiB/s, done.
# Resolving deltas: 100% (140/140), done.
# Updating files: 100% (161/161), done.

# %%
'''
cd if already has the repository.
'''

# %cd /kaggle/working/determining_and_erasing_kns_in_transformer_thesis/src/
# Out:
# /kaggle/working/knowledge-neurons-thesis/src

# %% [markdown]
# # Install packages

# %%
# !pip install jsonlines
# !pip install transformers==4.20.0
# Out:
# ...
# WARNING: Error parsing requirements for aiohttp: [Errno 2] No such file or directory: '/opt/conda/lib/python3.10/site-packages/aiohttp-3.9.1.dist-info/METADATA'
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.3/77.3 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 35.7 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 86.8 MB/s eta 0:00:00:00:0100:01
# WARNING: Error parsing requirements for aiohttp: [Errno 2] No such file or directory: '/opt/conda/lib/python3.10/site-packages/aiohttp-3.9.1.dist-info/METADATA'
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.41.1
#     Uninstalling transformers-4.41.1:
#       Successfully uninstalled transformers-4.41.1
# ...

# %% [markdown]
# # /src/2_analyze_kn.py

# %%
# !python 2_analyze_kn.py
# Out:
# average ig_kn 4.13378758382003
# average base_kn 3.963227341553104
# ig kn has on average 1.227880558762574 inner kn interseciton
# ig kn has on average 0.09321904967914053 inter kn interseciton
# base kn has on average 2.846608222014171 inner kn interseciton
# base kn has on average 1.9234559088614898 inter kn interseciton
