# %% [markdown]
# Thesis implementation [Knowledge Neurons in Pretrained Transformers](https://github.com/Thaifitus/knowledge-neurons-thesis.git) execution.

# %% [markdown]
# ## Clone repository

# %%
'''
git clone specified branch.
'''

# !git clone --branch hoangthai https://github.com/Thaifitus/knowledge-neurons-thesis.git
# Out:
# Cloning into 'knowledge-neurons-thesis'...
# remote: Enumerating objects: 358, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 358 (delta 70), reused 79 (delta 40), pack-reused 233
# Receiving objects: 100% (358/358), 156.54 MiB | 14.81 MiB/s, done.
# Resolving deltas: 100% (140/140), done.
# Updating files: 100% (161/161), done.

# %%
'''
cd if already has the repository.
'''

# %cd /kaggle/working/knowledge-neurons-thesis/src/
# Out:
# /kaggle/working/knowledge-neurons-thesis/src

# %% [markdown]
# ## Install packages

# %%
# !pip install jsonlines
# !pip install transformers==4.20.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.3/77.3 kB 1.9 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 38.7 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 71.4 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.2
#     Uninstalling tokenizers-0.15.2:
#       Successfully uninstalled tokenizers-0.15.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.38.2
#     Uninstalling transformers-4.38.2:
#       Successfully uninstalled transformers-4.38.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kaggle-environments 1.14.3 requires transformers>=4.33.1, but you have transformers 4.20.0 which is incompatible.
# ...

# %% [markdown]
# ### /src/1_analyze_mlm.py

# %%
# !bash 1_run_mlm.sh P127
# Out:
# device: cuda:0 n_gpu: 1, distributed training: False
# Downloading: 100%|████████████████████████████| 208k/208k [00:00<00:00, 535kB/s]
# Downloading: 100%|████████████████████████████| 49.0/49.0 [00:00<00:00, 289kB/s]
# Downloading: 100%|█████████████████████████████| 570/570 [00:00<00:00, 2.95MB/s]
# ***** CUDA.empty_cache() *****
# Downloading: 100%|███████████████████████████| 386M/386M [00:25<00:00, 16.0MB/s]
