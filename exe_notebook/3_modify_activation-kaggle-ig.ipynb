# %% [markdown]
# Thesis implementation [Knowledge Neurons in Pretrained Transformers](https://github.com/Thaifitus/knowledge-neurons-thesis.git) execution.

# %% [markdown]
# ## Clone repository

# %%
'''
git clone specified branch.
'''

# !git clone --branch temp_branch https://github.com/Thaifitus/kn_thesis.git
# Out:
# Cloning into 'kn_thesis'...
# remote: Enumerating objects: 248, done.
# remote: Counting objects: 100% (94/94), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 248 (delta 77), reused 89 (delta 73), pack-reused 154
# Receiving objects: 100% (248/248), 94.41 MiB | 12.85 MiB/s, done.
# Resolving deltas: 100% (88/88), done.
# Updating files: 100% (211/211), done.

# %%
'''
cd if already has the repository.
'''

# %cd /kaggle/working/kn_thesis/src/
# Out:
# /kaggle/working/kn_thesis/src

# %% [markdown]
# ## Install packages

# %%
# !pip install jsonlines
# !pip install transformers==4.20.0
# Out:
# Collecting jsonlines
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonlines) (23.2.0)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# WARNING: Error parsing requirements for aiohttp: [Errno 2] No such file or directory: '/opt/conda/lib/python3.10/site-packages/aiohttp-3.9.1.dist-info/METADATA'
# Installing collected packages: jsonlines
# Successfully installed jsonlines-4.0.0
# Collecting transformers==4.20.0
#   Downloading transformers-4.20.0-py3-none-any.whl.metadata (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.3/77.3 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers==4.20.0) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from transformers==4.20.0) (0.23.2)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers==4.20.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers==4.20.0) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers==4.20.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers==4.20.0) (2023.12.25)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers==4.20.0) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1 (from transformers==4.20.0)
#   Downloading tokenizers-0.12.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.5 kB)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers==4.20.0) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.20.0) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.20.0) (4.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers==4.20.0) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.20.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.20.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.20.0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.20.0) (2024.2.2)
# Downloading transformers-4.20.0-py3-none-any.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 82.4 MB/s eta 0:00:00:00:01
# Downloading tokenizers-0.12.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 91.6 MB/s eta 0:00:00:00:0100:01
# WARNING: Error parsing requirements for aiohttp: [Errno 2] No such file or directory: '/opt/conda/lib/python3.10/site-packages/aiohttp-3.9.1.dist-info/METADATA'
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.41.1
#     Uninstalling transformers-4.41.1:
#       Successfully uninstalled transformers-4.41.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kaggle-environments 1.14.9 requires transformers>=4.33.1, but you have transformers 4.20.0 which is incompatible.
# Successfully installed tokenizers-0.12.1 transformers-4.20.0

# %% [markdown]
# ### /src/3_modify_activation.py

# %%
# !bash 3_run_modify_activation.sh
# Out:
# Downloading: 100%|███████████████████████████| 208k/208k [00:00<00:00, 24.6MB/s]
# Downloading: 100%|████████████████████████████| 49.0/49.0 [00:00<00:00, 226kB/s]
# Downloading: 100%|█████████████████████████████| 570/570 [00:00<00:00, 3.22MB/s]
# Downloading: 100%|███████████████████████████| 386M/386M [00:25<00:00, 15.7MB/s]
# calculating relation P19 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# calculating bag 699 ...
# calculating bag 799 ...
# calculating bag 899 ...
# ***** Relation: P19 evaluated. Costing time: 1063.7804 seconds *****
# calculating relation P140 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# ***** Relation: P140 evaluated. Costing time: 332.9815 seconds *****
# calculating relation P136 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# calculating bag 699 ...
# calculating bag 799 ...
# calculating bag 899 ...
# ***** Relation: P136 evaluated. Costing time: 754.1675 seconds *****
# calculating relation P138 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# ***** Relation: P138 evaluated. Costing time: 958.1293 seconds *****
# calculating relation P740 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# calculating bag 699 ...
# calculating bag 799 ...
# calculating bag 899 ...
# ***** Relation: P740 evaluated. Costing time: 1117.7505 seconds *****
# calculating relation P1303 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# calculating bag 699 ...
# calculating bag 799 ...
# calculating bag 899 ...
# ***** Relation: P1303 evaluated. Costing time: 660.5247 seconds *****
# calculating relation P364 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# calculating bag 699 ...
# calculating bag 799 ...
# ***** Relation: P364 evaluated. Costing time: 695.5789 seconds *****
# calculating relation P495 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# calculating bag 699 ...
# calculating bag 799 ...
# calculating bag 899 ...
# ***** Relation: P495 evaluated. Costing time: 1218.4424 seconds *****
# calculating relation P36 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# calculating bag 699 ...
# ***** Relation: P36 evaluated. Costing time: 838.3398 seconds *****
# calculating relation P101 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# ***** Relation: P101 evaluated. Costing time: 800.3631 seconds *****
# calculating relation P413 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# calculating bag 699 ...
# calculating bag 799 ...
# calculating bag 899 ...
# ***** Relation: P413 evaluated. Costing time: 734.6373 seconds *****
# calculating relation P407 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# calculating bag 699 ...
# calculating bag 799 ...
# ***** Relation: P407 evaluated. Costing time: 1221.2134 seconds *****
# calculating relation P1412 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# calculating bag 699 ...
# calculating bag 799 ...
# calculating bag 899 ...
# ***** Relation: P1412 evaluated. Costing time: 850.0990 seconds *****
# calculating relation P20 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# calculating bag 699 ...
# calculating bag 799 ...
# calculating bag 899 ...
# ***** Relation: P20 evaluated. Costing time: 850.2095 seconds *****
# calculating relation P103 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# calculating bag 699 ...
# calculating bag 799 ...
# calculating bag 899 ...
# ***** Relation: P103 evaluated. Costing time: 673.2235 seconds *****
# calculating relation P463 ...
# calculating bag 99 ...
# calculating bag 199 ...
# ***** Relation: P463 evaluated. Costing time: 174.5705 seconds *****
# calculating relation P190 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# calculating bag 699 ...
# calculating bag 799 ...
# calculating bag 899 ...
# ***** Relation: P190 evaluated. Costing time: 689.7715 seconds *****
# calculating relation P530 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# calculating bag 699 ...
# calculating bag 799 ...
# calculating bag 899 ...
# ***** Relation: P530 evaluated. Costing time: 932.0423 seconds *****
# calculating relation P27 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# calculating bag 699 ...
# calculating bag 799 ...
# calculating bag 899 ...
# ***** Relation: P27 evaluated. Costing time: 900.5394 seconds *****
# calculating relation P30 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# calculating bag 699 ...
# calculating bag 799 ...
# calculating bag 899 ...
# ***** Relation: P30 evaluated. Costing time: 666.3640 seconds *****
# calculating relation P39 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# calculating bag 699 ...
# calculating bag 799 ...
# ***** Relation: P39 evaluated. Costing time: 690.7987 seconds *****
# calculating relation P178 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# ***** Relation: P178 evaluated. Costing time: 750.6864 seconds *****
# calculating relation P937 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# calculating bag 699 ...
# calculating bag 799 ...
# calculating bag 899 ...
# ***** Relation: P937 evaluated. Costing time: 721.2378 seconds *****
# calculating relation P37 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# calculating bag 699 ...
# calculating bag 799 ...
# calculating bag 899 ...
# ***** Relation: P37 evaluated. Costing time: 921.0297 seconds *****
# calculating relation P449 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# calculating bag 699 ...
# calculating bag 799 ...
# ***** Relation: P449 evaluated. Costing time: 894.3560 seconds *****
# calculating relation P106 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# calculating bag 699 ...
# calculating bag 799 ...
# calculating bag 899 ...
# ***** Relation: P106 evaluated. Costing time: 983.3135 seconds *****
# calculating relation P264 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# ***** Relation: P264 evaluated. Costing time: 574.7770 seconds *****
# calculating relation P159 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# calculating bag 699 ...
# calculating bag 799 ...
# calculating bag 899 ...
# ***** Relation: P159 evaluated. Costing time: 948.6007 seconds *****
# calculating relation P1376 ...
# calculating bag 99 ...
# calculating bag 199 ...
# ***** Relation: P1376 evaluated. Costing time: 279.7141 seconds *****
# calculating relation P279 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# calculating bag 699 ...
# calculating bag 799 ...
# calculating bag 899 ...
# ***** Relation: P279 evaluated. Costing time: 668.9577 seconds *****
# calculating relation P127 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# ***** Relation: P127 evaluated. Costing time: 477.2408 seconds *****
# calculating relation P176 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# calculating bag 699 ...
# calculating bag 799 ...
# calculating bag 899 ...
# ***** Relation: P176 evaluated. Costing time: 1068.7689 seconds *****
# calculating relation P47 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# calculating bag 399 ...
# calculating bag 499 ...
# calculating bag 599 ...
# calculating bag 699 ...
# calculating bag 799 ...
# calculating bag 899 ...
# ***** Relation: P47 evaluated. Costing time: 858.3040 seconds *****
# calculating relation P108 ...
# calculating bag 99 ...
# calculating bag 199 ...
# calculating bag 299 ...
# ***** Relation: P108 evaluated. Costing time: 263.1770 seconds *****
# calculating base_relation P449 ...
# calculating base_bag 99 ...
# calculating base_bag 199 ...
# calculating base_bag 299 ...
# calculating base_bag 399 ...
# calculating base_bag 499 ...
# calculating base_bag 599 ...
# calculating base_bag 699 ...
# calculating base_bag 799 ...
# ***** Relation: P449 evaluated. Costing time: 916.7435 seconds *****
# calculating base_relation P159 ...
# calculating base_bag 99 ...
# calculating base_bag 199 ...
# calculating base_bag 299 ...
# calculating base_bag 399 ...
# calculating base_bag 499 ...
# calculating base_bag 599 ...
# calculating base_bag 699 ...
# calculating base_bag 799 ...
# calculating base_bag 899 ...
# ***** Relation: P159 evaluated. Costing time: 938.2330 seconds *****
# calculating base_relation P136 ...
# calculating base_bag 99 ...
# calculating base_bag 199 ...
# calculating base_bag 299 ...
# calculating base_bag 399 ...
# calculating base_bag 499 ...
# calculating base_bag 599 ...
# calculating base_bag 699 ...
# calculating base_bag 799 ...
# calculating base_bag 899 ...
# ***** Relation: P136 evaluated. Costing time: 730.4380 seconds *****
# calculating base_relation P127 ...
# calculating base_bag 99 ...
# calculating base_bag 199 ...
# calculating base_bag 299 ...
# calculating base_bag 399 ...
# calculating base_bag 499 ...
# calculating base_bag 599 ...
# ***** Relation: P127 evaluated. Costing time: 463.0704 seconds *****
# calculating base_relation P190 ...
# calculating base_bag 99 ...
# calculating base_bag 199 ...
# calculating base_bag 299 ...
# calculating base_bag 399 ...
# calculating base_bag 499 ...
# calculating base_bag 599 ...
# calculating base_bag 699 ...
# calculating base_bag 799 ...
# calculating base_bag 899 ...
# ***** Relation: P190 evaluated. Costing time: 690.9607 seconds *****
# calculating base_relation P740 ...
# calculating base_bag 99 ...
# calculating base_bag 199 ...
# calculating base_bag 299 ...
# calculating base_bag 399 ...
# calculating base_bag 499 ...
# calculating base_bag 599 ...
# calculating base_bag 699 ...
# calculating base_bag 799 ...
# calculating base_bag 899 ...
# ***** Relation: P740 evaluated. Costing time: 1109.1936 seconds *****
# calculating base_relation P108 ...
# calculating base_bag 99 ...
# calculating base_bag 199 ...
# calculating base_bag 299 ...
# ***** Relation: P108 evaluated. Costing time: 259.5126 seconds *****
# calculating base_relation P264 ...
# calculating base_bag 99 ...
# calculating base_bag 199 ...
# calculating base_bag 299 ...
# calculating base_bag 399 ...
# ***** Relation: P264 evaluated. Costing time: 567.9033 seconds *****
# calculating base_relation P106 ...
# calculating base_bag 99 ...
# calculating base_bag 199 ...
# calculating base_bag 299 ...
# calculating base_bag 399 ...
# calculating base_bag 499 ...
# calculating base_bag 599 ...
# calculating base_bag 699 ...
# calculating base_bag 799 ...
# calculating base_bag 899 ...
# ***** Relation: P106 evaluated. Costing time: 979.3385 seconds *****
# calculating base_relation P1376 ...
# calculating base_bag 99 ...
# calculating base_bag 199 ...
# ***** Relation: P1376 evaluated. Costing time: 267.7801 seconds *****
# calculating base_relation P1303 ...
# calculating base_bag 99 ...
# calculating base_bag 199 ...
# calculating base_bag 299 ...
# calculating base_bag 399 ...
# calculating base_bag 499 ...
# calculating base_bag 599 ...
# calculating base_bag 699 ...
# calculating base_bag 799 ...
# calculating base_bag 899 ...
# ***** Relation: P1303 evaluated. Costing time: 637.4503 seconds *****
# calculating base_relation P103 ...
# calculating base_bag 99 ...
# calculating base_bag 199 ...
# calculating base_bag 299 ...
# calculating base_bag 399 ...
# calculating base_bag 499 ...
# calculating base_bag 599 ...
# calculating base_bag 699 ...
# calculating base_bag 799 ...
# calculating base_bag 899 ...
# ***** Relation: P103 evaluated. Costing time: 672.3092 seconds *****
# calculating base_relation P138 ...
# calculating base_bag 99 ...
# calculating base_bag 199 ...
# calculating base_bag 299 ...
# calculating base_bag 399 ...
# calculating base_bag 499 ...
# calculating base_bag 599 ...
# ***** Relation: P138 evaluated. Costing time: 936.4983 seconds *****
# calculating base_relation P37 ...
# calculating base_bag 99 ...
# calculating base_bag 199 ...
# calculating base_bag 299 ...
# calculating base_bag 399 ...
# calculating base_bag 499 ...
# calculating base_bag 599 ...
# calculating base_bag 699 ...
# calculating base_bag 799 ...
# calculating base_bag 899 ...
# ***** Relation: P37 evaluated. Costing time: 883.8248 seconds *****
# calculating base_relation P140 ...
# calculating base_bag 99 ...
# calculating base_bag 199 ...
# calculating base_bag 299 ...
# calculating base_bag 399 ...
# ***** Relation: P140 evaluated. Costing time: 317.3764 seconds *****
# calculating base_relation P279 ...
# calculating base_bag 99 ...
# calculating base_bag 199 ...
# calculating base_bag 299 ...
# calculating base_bag 399 ...
# calculating base_bag 499 ...
# calculating base_bag 599 ...
# calculating base_bag 699 ...
# calculating base_bag 799 ...
# calculating base_bag 899 ...
# ***** Relation: P279 evaluated. Costing time: 667.0883 seconds *****
# calculating base_relation P1412 ...
# calculating base_bag 99 ...
# calculating base_bag 199 ...
# calculating base_bag 299 ...
# calculating base_bag 399 ...
