# %% [markdown]
# Thesis implementation [Knowledge Neurons in Pretrained Transformers](https://github.com/Thaifitus/knowledge-neurons-thesis.git) execution.

# %% [markdown]
# ## Clone repository

# %%
'''
git clone specified branch.
'''

# !git clone --branch temp_branch https://github.com/Thaifitus/knowledge-neurons-thesis.git
# %cd /kaggle/working/knowledge-neurons-thesis/src/
# Out:
# Cloning into 'knowledge-neurons-thesis'...
# remote: Enumerating objects: 450, done.
# remote: Counting objects: 100% (178/178), done.
# remote: Compressing objects: 100% (95/95), done.
# remote: Total 450 (delta 109), reused 124 (delta 78), pack-reused 272
# Receiving objects: 100% (450/450), 166.84 MiB | 23.07 MiB/s, done.
# Resolving deltas: 100% (194/194), done.
# Updating files: 100% (145/145), done.
# /kaggle/working/knowledge-neurons-thesis/src

# %% [markdown]
# ## Install packages

# %%
# !pip install jsonlines
# !pip install transformers==4.20.0
# Out:
# Collecting jsonlines
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonlines) (23.2.0)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Installing collected packages: jsonlines
# Successfully installed jsonlines-4.0.0
# Collecting transformers==4.20.0
#   Downloading transformers-4.20.0-py3-none-any.whl.metadata (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.3/77.3 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers==4.20.0) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from transformers==4.20.0) (0.22.2)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers==4.20.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers==4.20.0) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers==4.20.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers==4.20.0) (2023.12.25)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers==4.20.0) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1 (from transformers==4.20.0)
#   Downloading tokenizers-0.12.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.5 kB)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers==4.20.0) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.20.0) (2024.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.20.0) (4.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers==4.20.0) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.20.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.20.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.20.0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.20.0) (2024.2.2)
# Downloading transformers-4.20.0-py3-none-any.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 62.6 MB/s eta 0:00:00:00:010:01
# Downloading tokenizers-0.12.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 90.5 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.2
#     Uninstalling tokenizers-0.15.2:
#       Successfully uninstalled tokenizers-0.15.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.39.3
#     Uninstalling transformers-4.39.3:
#       Successfully uninstalled transformers-4.39.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kaggle-environments 1.14.3 requires transformers>=4.33.1, but you have transformers 4.20.0 which is incompatible.
# Successfully installed tokenizers-0.12.1 transformers-4.20.0

# %%
# !bash 7_run_erase.sh P19
# Out:
# Downloading: 100%|███████████████████████████| 208k/208k [00:00<00:00, 8.74MB/s]
# Downloading: 100%|████████████████████████████| 49.0/49.0 [00:00<00:00, 273kB/s]
# Downloading: 100%|█████████████████████████████| 570/570 [00:00<00:00, 3.05MB/s]
# evaluating P19...
# [('10@739', 613), ('11@2876', 444), ('10@1885', 244), ('10@2015', 194), ('11@112', 138), ('11@2194', 54), ('9@369', 50), ('10@1692', 44), ('11@1761', 41), ('10@1169', 30), ('10@1845', 29), ('11@1186', 29), ('11@1205', 27), ('11@1754', 21), ('11@86', 20), ('11@1651', 17), ('11@2414', 16), ('11@2003', 15), ('9@1183', 15), ('11@1657', 14)]
# Downloading: 100%|███████████████████████████| 386M/386M [00:10<00:00, 38.6MB/s]
#
#
# erasing -- kn_num: 20
#
# ***** P19 erased. Costing time: 405.5148 seconds *****
# ======================================== P19 ===========================================
# original accuracy: 0.03178
# erased accuracy: 0.03422
# erased ratio: -0.07692
# # Kneurons: 20
# original ppl: 1.45e+03
# erased ppl: 2.996e+03
# ppl increasing ratio: -1.066

# %%
# !bash 7_run_erase.sh P106
# Out:
# evaluating P106...
# [('11@1921', 794), ('10@1804', 321), ('9@3042', 272), ('9@1925', 209), ('11@1520', 183), ('11@678', 127), ('9@646', 89), ('10@664', 67), ('10@1440', 56), ('11@1350', 51), ('10@1963', 34), ('10@1810', 24), ('11@1167', 7), ('10@1996', 3), ('11@3015', 3), ('11@1488', 3), ('8@2132', 3), ('11@1408', 2), ('11@2870', 2), ('11@1825', 2)]
#
#
# erasing -- kn_num: 20
#
# ***** P106 erased. Costing time: 351.5769 seconds *****
# ======================================== P106 ===========================================
# original accuracy: 0.02258
# erased accuracy: 0.01329
# erased ratio: 0.4118
# # Kneurons: 20
# original ppl: 2.279e+03
# erased ppl: 5.202e+03
# ppl increasing ratio: -1.282

# %% [markdown]
# ### /src/7_run_erase.sh

# %%
# !bash 7_run_erase.sh P937
# Out:
# Downloading: 100%|███████████████████████████| 208k/208k [00:00<00:00, 1.29MB/s]
# Downloading: 100%|████████████████████████████| 49.0/49.0 [00:00<00:00, 351kB/s]
# Downloading: 100%|█████████████████████████████| 570/570 [00:00<00:00, 4.29MB/s]
# evaluating P937...
# [('10@1122', 899), ('10@739', 638), ('10@472', 637), ('9@369', 555), ('11@1657', 464), ('8@2645', 323), ('9@2125', 292), ('10@1294', 284), ('9@2994', 284), ('8@1519', 247), ('11@622', 236), ('9@2700', 208), ('10@183', 202), ('11@1384', 168), ('9@710', 153), ('9@2058', 153), ('9@1311', 131), ('10@3008', 117), ('8@1536', 114), ('10@126', 102)]
# Downloading: 100%|███████████████████████████| 386M/386M [00:15<00:00, 26.0MB/s]
#
#
# erasing -- kn_num: 20
#
# ***** P937 erased. Costing time: 157.4891 seconds *****
# ======================================== P937 ===========================================
# original accuracy: 0.3338
# erased accuracy: 0.1229
# erased ratio: 0.6319
# # Kneurons: 20
# original ppl: 58.04
# erased ppl: 140.0
# ppl increasing ratio: -1.412
